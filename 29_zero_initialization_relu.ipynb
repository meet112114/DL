# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./resources/ushape.csv' , names=['X', 'Y','class'])

# %%
df.head()
# Out:
#           X         Y  class
# 0  0.031595  0.986988    0.0
# 1  2.115098 -0.046244    1.0
# 2  0.882490 -0.075756    0.0
# 3 -0.055144 -0.037332    1.0
# 4  0.829545 -0.539321    1.0

# %%
plt.scatter(df['X'],df['Y'],c=df['class'])

# %%
X = df.iloc[:,0:2].values
y = df.iloc[:,-1].values

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(2,activation='sigmoid',input_dim=2))
model.add(Dense(1,activation='sigmoid'))

model.summary()
# Out:
# c:\Users\mrsan\OneDrive\Desktop\code\python\venv\lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 2)              │             6 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9 (36.00 B)
#  Trainable params: 9 (36.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Set parameters to 0
model.get_weights()
# Out:
# [array([[ 0.35029578, -1.0286455 ],
#         [ 0.08391488,  0.19082797]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[ 0.8592619],
#         [-1.3911097]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
initial_weights = model.get_weights()

# %%
initial_weights[0] = np.ones(model.get_weights()[0].shape)*0.5
initial_weights[1] = np.ones(model.get_weights()[1].shape)*0.5
initial_weights[2] = np.ones(model.get_weights()[2].shape)*0.5
initial_weights[3] = np.ones(model.get_weights()[3].shape)*0.5

# %%
model.set_weights(initial_weights)

# %%
model.get_weights()
# Out:
# [array([[0.5, 0.5],
#         [0.5, 0.5]], dtype=float32),
#  array([0.5, 0.5], dtype=float32),
#  array([[0.5],
#         [0.5]], dtype=float32),
#  array([0.5], dtype=float32)]

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
history = model.fit(X,y,epochs=100,validation_split=0.2)
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - accuracy: 0.5000 - loss: 0.8635 - val_accuracy: 0.5000 - val_loss: 0.8362
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5000 - loss: 0.8612 - val_accuracy: 0.5000 - val_loss: 0.8340
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5000 - loss: 0.8588 - val_accuracy: 0.5000 - val_loss: 0.8319
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5000 - loss: 0.8569 - val_accuracy: 0.5000 - val_loss: 0.8297
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5000 - loss: 0.8545 - val_accuracy: 0.5000 - val_loss: 0.8277
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5000 - loss: 0.8525 - val_accuracy: 0.5000 - val_loss: 0.8256
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5000 - loss: 0.8501 - val_accuracy: 0.5000 - val_loss: 0.8236
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5000 - loss: 0.8482 - val_accuracy: 0.5000 - val_loss: 0.8216
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.5000 - loss: 0.8461 - val_accuracy: 0.5000 - val_loss: 0.8196
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.5000 - loss: 0.8439 - val_accuracy: 0.5000 - val_loss: 0.8176
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5000 - loss: 0.8418 - val_accuracy: 0.5000 - val_loss: 0.8156
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5000 - loss: 0.8397 - val_accuracy: 0.5000 - val_loss: 0.8137
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5000 - loss: 0.8378 - val_accuracy: 0.5000 - val_loss: 0.8118
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5000 - loss: 0.8357 - val_accuracy: 0.5000 - val_loss: 0.8099
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5000 - loss: 0.8339 - val_accuracy: 0.5000 - val_loss: 0.8080
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.5000 - loss: 0.8318 - val_accuracy: 0.5000 - val_loss: 0.8061
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5000 - loss: 0.8298 - val_accuracy: 0.5000 - val_loss: 0.8043
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5000 - loss: 0.8282 - val_accuracy: 0.5000 - val_loss: 0.8025
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5000 - loss: 0.8261 - val_accuracy: 0.5000 - val_loss: 0.8008
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5000 - loss: 0.8244 - val_accuracy: 0.5000 - val_loss: 0.7990
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5000 - loss: 0.8225 - val_accuracy: 0.5000 - val_loss: 0.7974
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5000 - loss: 0.8208 - val_accuracy: 0.5000 - val_loss: 0.7957
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5000 - loss: 0.8189 - val_accuracy: 0.5000 - val_loss: 0.7941
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5000 - loss: 0.8173 - val_accuracy: 0.5000 - val_loss: 0.7924
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5000 - loss: 0.8156 - val_accuracy: 0.5000 - val_loss: 0.7908
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5000 - loss: 0.8139 - val_accuracy: 0.5000 - val_loss: 0.7892
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5000 - loss: 0.8122 - val_accuracy: 0.5000 - val_loss: 0.7876
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5000 - loss: 0.8103 - val_accuracy: 0.5000 - val_loss: 0.7861
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5000 - loss: 0.8090 - val_accuracy: 0.5000 - val_loss: 0.7845
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5000 - loss: 0.8072 - val_accuracy: 0.5000 - val_loss: 0.7830
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5000 - loss: 0.8057 - val_accuracy: 0.5000 - val_loss: 0.7815
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5000 - loss: 0.8039 - val_accuracy: 0.5000 - val_loss: 0.7801
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5000 - loss: 0.8025 - val_accuracy: 0.5000 - val_loss: 0.7786
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5000 - loss: 0.8010 - val_accuracy: 0.5000 - val_loss: 0.7771
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5000 - loss: 0.7992 - val_accuracy: 0.5000 - val_loss: 0.7757
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5000 - loss: 0.7979 - val_accuracy: 0.5000 - val_loss: 0.7743
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5000 - loss: 0.7962 - val_accuracy: 0.5000 - val_loss: 0.7729
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5000 - loss: 0.7947 - val_accuracy: 0.5000 - val_loss: 0.7715
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5000 - loss: 0.7933 - val_accuracy: 0.5000 - val_loss: 0.7700
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5000 - loss: 0.7918 - val_accuracy: 0.5000 - val_loss: 0.7687
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5000 - loss: 0.7903 - val_accuracy: 0.5000 - val_loss: 0.7673
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5000 - loss: 0.7888 - val_accuracy: 0.5000 - val_loss: 0.7660
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5000 - loss: 0.7874 - val_accuracy: 0.5000 - val_loss: 0.7648
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5000 - loss: 0.7861 - val_accuracy: 0.5000 - val_loss: 0.7635
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5000 - loss: 0.7847 - val_accuracy: 0.5000 - val_loss: 0.7622
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5000 - loss: 0.7834 - val_accuracy: 0.5000 - val_loss: 0.7610
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5000 - loss: 0.7820 - val_accuracy: 0.5000 - val_loss: 0.7598
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5000 - loss: 0.7807 - val_accuracy: 0.5000 - val_loss: 0.7585
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5000 - loss: 0.7793 - val_accuracy: 0.5000 - val_loss: 0.7573
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5000 - loss: 0.7779 - val_accuracy: 0.5000 - val_loss: 0.7561
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5000 - loss: 0.7766 - val_accuracy: 0.5000 - val_loss: 0.7548
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5000 - loss: 0.7753 - val_accuracy: 0.5000 - val_loss: 0.7536
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5000 - loss: 0.7741 - val_accuracy: 0.5000 - val_loss: 0.7524
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5000 - loss: 0.7726 - val_accuracy: 0.5000 - val_loss: 0.7512
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5000 - loss: 0.7714 - val_accuracy: 0.5000 - val_loss: 0.7500
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5000 - loss: 0.7701 - val_accuracy: 0.5000 - val_loss: 0.7489
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5000 - loss: 0.7689 - val_accuracy: 0.5000 - val_loss: 0.7478
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5000 - loss: 0.7676 - val_accuracy: 0.5000 - val_loss: 0.7467
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5000 - loss: 0.7665 - val_accuracy: 0.5000 - val_loss: 0.7456
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5000 - loss: 0.7653 - val_accuracy: 0.5000 - val_loss: 0.7445
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5000 - loss: 0.7642 - val_accuracy: 0.5000 - val_loss: 0.7434
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5000 - loss: 0.7629 - val_accuracy: 0.5000 - val_loss: 0.7424
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5000 - loss: 0.7618 - val_accuracy: 0.5000 - val_loss: 0.7413
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5000 - loss: 0.7607 - val_accuracy: 0.5000 - val_loss: 0.7403
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5000 - loss: 0.7595 - val_accuracy: 0.5000 - val_loss: 0.7393
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5000 - loss: 0.7585 - val_accuracy: 0.5000 - val_loss: 0.7383
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5000 - loss: 0.7574 - val_accuracy: 0.5000 - val_loss: 0.7374
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5000 - loss: 0.7563 - val_accuracy: 0.5000 - val_loss: 0.7365
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5000 - loss: 0.7553 - val_accuracy: 0.5000 - val_loss: 0.7355
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5000 - loss: 0.7542 - val_accuracy: 0.5000 - val_loss: 0.7346
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5000 - loss: 0.7534 - val_accuracy: 0.5000 - val_loss: 0.7337
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5000 - loss: 0.7523 - val_accuracy: 0.5000 - val_loss: 0.7328
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5000 - loss: 0.7514 - val_accuracy: 0.5000 - val_loss: 0.7319
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5000 - loss: 0.7504 - val_accuracy: 0.5000 - val_loss: 0.7310
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5000 - loss: 0.7494 - val_accuracy: 0.5000 - val_loss: 0.7302
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5000 - loss: 0.7483 - val_accuracy: 0.5000 - val_loss: 0.7293
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5000 - loss: 0.7475 - val_accuracy: 0.5000 - val_loss: 0.7285
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5000 - loss: 0.7466 - val_accuracy: 0.5000 - val_loss: 0.7276
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5000 - loss: 0.7454 - val_accuracy: 0.5000 - val_loss: 0.7268
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5000 - loss: 0.7445 - val_accuracy: 0.5000 - val_loss: 0.7260
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5000 - loss: 0.7436 - val_accuracy: 0.5000 - val_loss: 0.7251
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5000 - loss: 0.7427 - val_accuracy: 0.5000 - val_loss: 0.7243
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5000 - loss: 0.7419 - val_accuracy: 0.5000 - val_loss: 0.7235
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5000 - loss: 0.7409 - val_accuracy: 0.5000 - val_loss: 0.7227
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5000 - loss: 0.7400 - val_accuracy: 0.5000 - val_loss: 0.7220
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5000 - loss: 0.7392 - val_accuracy: 0.5000 - val_loss: 0.7212
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5000 - loss: 0.7384 - val_accuracy: 0.5000 - val_loss: 0.7205
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5000 - loss: 0.7376 - val_accuracy: 0.5000 - val_loss: 0.7198
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5000 - loss: 0.7367 - val_accuracy: 0.5000 - val_loss: 0.7191
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5000 - loss: 0.7359 - val_accuracy: 0.5000 - val_loss: 0.7184
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5000 - loss: 0.7351 - val_accuracy: 0.5000 - val_loss: 0.7177
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5000 - loss: 0.7344 - val_accuracy: 0.5000 - val_loss: 0.7170
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5000 - loss: 0.7337 - val_accuracy: 0.5000 - val_loss: 0.7164
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5000 - loss: 0.7329 - val_accuracy: 0.5000 - val_loss: 0.7158
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5000 - loss: 0.7321 - val_accuracy: 0.5000 - val_loss: 0.7151
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5000 - loss: 0.7314 - val_accuracy: 0.5000 - val_loss: 0.7145
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5000 - loss: 0.7307 - val_accuracy: 0.5000 - val_loss: 0.7139
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5000 - loss: 0.7300 - val_accuracy: 0.5000 - val_loss: 0.7132
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5000 - loss: 0.7293 - val_accuracy: 0.5000 - val_loss: 0.7126
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5000 - loss: 0.7286 - val_accuracy: 0.5000 - val_loss: 0.7120

# %%
model.get_weights()
# Out:
# [array([[0.7172109 , 0.7172109 ],
#         [0.24578024, 0.24578024]], dtype=float32),
#  array([0.27525, 0.27525], dtype=float32),
#  array([[0.26496512],
#         [0.26496512]], dtype=float32),
#  array([0.25148994], dtype=float32)]

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X,y.astype('int'), clf=model, legend=2)
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# <Axes: >
